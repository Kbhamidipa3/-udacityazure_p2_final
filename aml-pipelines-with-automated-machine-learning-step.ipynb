# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
# !pip list | grep 1.19.0 | xargs pip uninstall -r
# !pip install azureml-sdk[automl,contrib,widgets]==1.18.0
# !pip3 install azureml.widgets
# Out:
# Usage:
#   pip uninstall [options] <package> ...
#   pip uninstall [options] -r <requirements file> ...
#
# -r option requires 1 argument
# Requirement already satisfied: azureml-sdk[automl,contrib,widgets]==1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.18.0)
#   WARNING: azureml-sdk 1.18.0 does not provide the extra 'widgets'
# Requirement already satisfied: azureml-core~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0.post4)
# Requirement already satisfied: azureml-train-automl-client~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0)
# Requirement already satisfied: azureml-dataset-runtime[fuse]~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0)
# Requirement already satisfied: azureml-train~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0)
# Requirement already satisfied: azureml-pipeline~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0)
# Requirement already satisfied: azureml-train-automl~=1.18.0; extra == "automl" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0)
# Requirement already satisfied: azureml-contrib-server~=1.18.0; extra == "contrib" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0)
# Requirement already satisfied: azureml-contrib-pipeline-steps~=1.18.0; extra == "contrib" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0)
# Requirement already satisfied: azureml-contrib-notebook~=1.18.0; extra == "contrib" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0)
# Requirement already satisfied: azureml-contrib-services~=1.18.0; extra == "contrib" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0)
# Requirement already satisfied: ndg-httpsclient in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.5.1)
# Requirement already satisfied: jsonpickle in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.4.2)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (3.2.1)
# Requirement already satisfied: SecretStorage in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (3.3.0)
# Requirement already satisfied: azure-mgmt-containerregistry>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (2.8.0)
# Requirement already satisfied: azure-mgmt-keyvault<7.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (2.2.0)
# Requirement already satisfied: docker in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (4.4.0)
# Requirement already satisfied: azure-common>=1.1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.1.26)
# Requirement already satisfied: azure-mgmt-resource<15.0.0,>=1.2.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (10.3.0)
# Requirement already satisfied: jmespath in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.10.0)
# Requirement already satisfied: msrest>=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.6.19)
# Requirement already satisfied: urllib3>=1.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.25.11)
# Requirement already satisfied: adal>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.2.5)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.61.1)
# Requirement already satisfied: requests>=2.19.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (2.25.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (2.8.1)
# Requirement already satisfied: PyJWT<2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.7.1)
# Requirement already satisfied: pyopenssl<20.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (19.1.0)
# Requirement already satisfied: pytz in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (2020.4)
# Requirement already satisfied: contextlib2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.6.0.post1)
# Requirement already satisfied: ruamel.yaml>=0.15.35 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.16.12)
# Requirement already satisfied: pathspec in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.8.1)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.0)
# Requirement already satisfied: azure-mgmt-authorization<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.61.0)
# Requirement already satisfied: msrestazure>=0.4.33 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.6.4)
# Requirement already satisfied: azure-mgmt-storage<16.0.0,>=1.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (11.2.0)
# Requirement already satisfied: azureml-telemetry~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-client~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0.post1)
# Requirement already satisfied: azureml-automl-core~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-client~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0.post2)
# Requirement already satisfied: pyarrow<2.0.0,>=0.17.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.0.1)
# Requirement already satisfied: azureml-dataprep<2.5.0a,>=2.4.0a in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (2.4.5)
# Requirement already satisfied: fusepy<4.0.0,>=3.0.1; extra == "fuse" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (3.0.1)
# Requirement already satisfied: azureml-train-core~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0.post1)
# Requirement already satisfied: azureml-pipeline-steps~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-pipeline~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0)
# Requirement already satisfied: azureml-pipeline-core~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-pipeline~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0)
# Requirement already satisfied: azureml-train-automl-runtime~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0.post1)
# Requirement already satisfied: azureml-automl-runtime~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0.post2)
# Requirement already satisfied: ipykernel in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (5.3.4)
# Requirement already satisfied: ipython in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (7.16.1)
# Requirement already satisfied: nbconvert<6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (5.6.1)
# Requirement already satisfied: papermill<2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.2.1)
# Requirement already satisfied: Flask<2.0,>=1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-services~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.0.3)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ndg-httpsclient->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.4.8)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonpickle->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (3.1.1)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.14.4)
# Requirement already satisfied: six>=1.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.15.0)
# Requirement already satisfied: jeepney>=0.6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from SecretStorage->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.6.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from docker->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.57.0)
# Requirement already satisfied: isodate>=0.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.6.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (2.10)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ruamel.yaml>=0.15.35->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.2.2)
# Requirement already satisfied: backports.weakref in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from backports.tempfile->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.0.post1)
# Requirement already satisfied: applicationinsights in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-telemetry~=1.18.0->azureml-train-automl-client~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.11.9)
# Requirement already satisfied: numpy>=1.14 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pyarrow<2.0.0,>=0.17.0->azureml-dataset-runtime[fuse]~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.5)
# Requirement already satisfied: cloudpickle<2.0.0,>=1.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse]~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.6.0)
# Requirement already satisfied: azure-identity<1.5.0,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse]~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.4.1)
# Requirement already satisfied: azureml-dataprep-native<25.0.0,>=24.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse]~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (24.0.0)
# Requirement already satisfied: dotnetcore2<3.0.0,>=2.1.14 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse]~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (2.1.19)
# Requirement already satisfied: azureml-dataprep-rslex<1.3.0a,>=1.2.0dev0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse]~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.2.3)
# Requirement already satisfied: azureml-train-restclients-hyperdrive~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-core~=1.18.0->azureml-train~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0)
# Requirement already satisfied: scikit-learn<0.23.0,>=0.19.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.22.2.post1)
# Requirement already satisfied: onnxruntime==1.3.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.3.0)
# Requirement already satisfied: botocore<=1.18.18 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.18)
# Requirement already satisfied: onnx<=1.7.0,>=1.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.7.0)
# Requirement already satisfied: onnxmltools==1.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.4.1)
# Requirement already satisfied: statsmodels<=0.10.2,>=0.9.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.10.2)
# Requirement already satisfied: jinja2<=2.11.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (2.11.2)
# Requirement already satisfied: azureml-defaults~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0)
# Requirement already satisfied: sklearn-pandas<=1.7.0,>=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.7.0)
# Requirement already satisfied: lightgbm<=2.3.0,>=2.0.11 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (2.3.0)
# Requirement already satisfied: pandas<1.0.0,>=0.21.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.25.3)
# Requirement already satisfied: scipy<=1.5.2,>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.5.2)
# Requirement already satisfied: onnxconverter-common<=1.6.0,>=1.4.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.6.0)
# Requirement already satisfied: keras2onnx<=1.6.0,>=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.6.0)
# Requirement already satisfied: azure-storage-queue~=12.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (12.1.4)
# Requirement already satisfied: boto3<=1.15.18 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.15.18)
# Requirement already satisfied: skl2onnx==1.4.9 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.4.9)
# Requirement already satisfied: gensim<3.9.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (3.8.3)
# Requirement already satisfied: smart-open<=1.9.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.9.0)
# Requirement already satisfied: azureml-interpret~=1.18.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.18.0)
# Requirement already satisfied: py-cpuinfo==5.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (5.0.0)
# Requirement already satisfied: psutil<6.0.0,>=5.2.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (5.7.3)
# Requirement already satisfied: nimbusml<=1.8.0,>=1.7.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.8.0)
# Requirement already satisfied: dill<0.4.0,>=0.2.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.3.3)
# Requirement already satisfied: joblib==0.14.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.14.1)
# Requirement already satisfied: pmdarima==1.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.1.1)
# Requirement already satisfied: tornado>=4.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipykernel->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (6.1)
# Requirement already satisfied: traitlets>=4.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipykernel->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (4.3.3)
# Requirement already satisfied: jupyter-client in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipykernel->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (6.1.7)
# Requirement already satisfied: jedi>=0.10 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.17.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (3.0.5)
# Requirement already satisfied: setuptools>=18.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (50.3.0.post20201006)
# Requirement already satisfied: pickleshare in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.7.5)
# Requirement already satisfied: pygments in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (2.7.3)
# Requirement already satisfied: backcall in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.2.0)
# Requirement already satisfied: decorator in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (4.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.3)
# Requirement already satisfied: jupyter-core in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (4.7.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.4.3)
# Requirement already satisfied: testpath in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.4.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.8.4)
# Requirement already satisfied: defusedxml in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.6.0)
# Requirement already satisfied: bleach in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (3.2.1)
# Requirement already satisfied: nbformat>=4.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (5.0.8)
# Requirement already satisfied: tenacity in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (6.2.0)
# Requirement already satisfied: future in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.18.2)
# Requirement already satisfied: tqdm>=4.32.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (4.54.0)
# Requirement already satisfied: pyyaml in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (5.3.1)
# Requirement already satisfied: ansiwrap in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.8.4)
# Requirement already satisfied: click in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from Flask<2.0,>=1.0->azureml-contrib-services~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.14 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from Flask<2.0,>=1.0->azureml-contrib-services~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.0.1)
# Requirement already satisfied: zipp>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (3.4.0)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (2.20)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (3.1.0)
# Requirement already satisfied: msal<2.0.0,>=1.3.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse]~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.6.0)
# Requirement already satisfied: msal-extensions~=0.2.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse]~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.2.2)
# Requirement already satisfied: azure-core<2.0.0,>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse]~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.9.0)
# Requirement already satisfied: distro>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from dotnetcore2<3.0.0,>=2.1.14->azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse]~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.5.0)
# Requirement already satisfied: protobuf in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from onnxruntime==1.3.0->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (3.14.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from onnx<=1.7.0,>=1.5.0->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (3.7.4.3)
# Requirement already satisfied: patsy>=0.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from statsmodels<=0.10.2,>=0.9.0->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jinja2<=2.11.2->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.1.1)
# Requirement already satisfied: configparser==3.7.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-defaults~=1.18.0->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (3.7.4)
# Requirement already satisfied: azureml-model-management-sdk==1.0.1b6.post1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-defaults~=1.18.0->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.0.1b6.post1)
# Requirement already satisfied: gunicorn==19.9.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-defaults~=1.18.0->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (19.9.0)
# Requirement already satisfied: json-logging-py==0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-defaults~=1.18.0->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.2)
# Requirement already satisfied: fire in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from keras2onnx<=1.6.0,>=1.4.0->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.3.1)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from boto3<=1.15.18->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.3.3)
# Requirement already satisfied: boto>=2.32 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from smart-open<=1.9.0->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (2.49.0)
# Requirement already satisfied: interpret-community==0.15.* in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-interpret~=1.18.0->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.15.4)
# Requirement already satisfied: Cython>=0.29 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pmdarima==1.1.1->azureml-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.29.21)
# Requirement already satisfied: ipython-genutils in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from traitlets>=4.1.0->ipykernel->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.2.0)
# Requirement already satisfied: pyzmq>=13 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jupyter-client->ipykernel->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (20.0.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jedi>=0.10->ipython->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.6.0)
# Requirement already satisfied: wcwidth in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.2.5)
# Requirement already satisfied: packaging in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from bleach->nbconvert<6->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (20.7)
# Requirement already satisfied: webencodings in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from bleach->nbconvert<6->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.5.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbformat>=4.4->nbconvert<6->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (3.2.0)
# Requirement already satisfied: textwrap3>=0.9.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ansiwrap->papermill<2->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.9.2)
# Requirement already satisfied: portalocker~=1.0; platform_system != "Windows" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msal-extensions~=0.2.2->azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse]~=1.18.0->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.7.1)
# Requirement already satisfied: liac-arff>=2.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.18.0->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (2.5.0)
# Requirement already satisfied: termcolor in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from fire->keras2onnx<=1.6.0,>=1.4.0->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (1.1.0)
# Requirement already satisfied: interpret-core[required]<=0.2.1,>=0.1.20 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from interpret-community==0.15.*->azureml-interpret~=1.18.0->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.2.1)
# Requirement already satisfied: shap<=0.34.0,>=0.20.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from interpret-community==0.15.*->azureml-interpret~=1.18.0->azureml-train-automl-runtime~=1.18.0->azureml-train-automl~=1.18.0; extra == "automl"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.34.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from packaging->bleach->nbconvert<6->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (2.4.7)
# Requirement already satisfied: pyrsistent>=0.14.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<6->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<6->azureml-contrib-notebook~=1.18.0; extra == "contrib"->azureml-sdk[automl,contrib,widgets]==1.18.0) (20.3.0)
# Collecting azureml.widgets
#   Downloading azureml_widgets-1.19.0-py3-none-any.whl (14.1 MB)
#      |████████████████████████████████| 14.1 MB 6.4 MB/s eta 0:00:01
# Collecting azureml-core~=1.19.0
#   Downloading azureml_core-1.19.0-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 53.9 MB/s eta 0:00:01
# Requirement already satisfied: ipywidgets>=7.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml.widgets) (7.5.1)
# Collecting azureml-telemetry~=1.19.0
#   Downloading azureml_telemetry-1.19.0-py3-none-any.whl (30 kB)
# Requirement already satisfied: jsonpickle in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (1.4.2)
# Requirement already satisfied: msrestazure>=0.4.33 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (0.6.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (2.8.1)
# Requirement already satisfied: msrest>=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (0.6.19)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (1.0)
# Requirement already satisfied: azure-mgmt-authorization<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (0.61.0)
# Requirement already satisfied: azure-mgmt-resource<15.0.0,>=1.2.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (10.3.0)
# Requirement already satisfied: contextlib2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (0.6.0.post1)
# Requirement already satisfied: azure-common>=1.1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (1.1.26)
# Requirement already satisfied: PyJWT<2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (1.7.1)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (3.2.1)
# Requirement already satisfied: pytz in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (2020.4)
# Requirement already satisfied: ndg-httpsclient in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (0.5.1)
# Requirement already satisfied: azure-mgmt-containerregistry>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (2.8.0)
# Requirement already satisfied: SecretStorage in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (3.3.0)
# Requirement already satisfied: requests>=2.19.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (2.25.0)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (0.61.1)
# Requirement already satisfied: urllib3>=1.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (1.25.11)
# Requirement already satisfied: pathspec in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (0.8.1)
# Requirement already satisfied: jmespath in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (0.10.0)
# Requirement already satisfied: adal>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (1.2.5)
# Requirement already satisfied: pyopenssl<20.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (19.1.0)
# Requirement already satisfied: docker in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (4.4.0)
# Requirement already satisfied: azure-mgmt-storage<16.0.0,>=1.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (11.2.0)
# Requirement already satisfied: ruamel.yaml>=0.15.35 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (0.16.12)
# Requirement already satisfied: azure-mgmt-keyvault<7.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.19.0->azureml.widgets) (2.2.0)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipywidgets>=7.0.0->azureml.widgets) (7.16.1)
# Requirement already satisfied: nbformat>=4.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipywidgets>=7.0.0->azureml.widgets) (5.0.8)
# Requirement already satisfied: ipykernel>=4.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipywidgets>=7.0.0->azureml.widgets) (5.3.4)
# Requirement already satisfied: traitlets>=4.3.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipywidgets>=7.0.0->azureml.widgets) (4.3.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipywidgets>=7.0.0->azureml.widgets) (3.5.1)
# Requirement already satisfied: applicationinsights in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-telemetry~=1.19.0->azureml.widgets) (0.11.9)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonpickle->azureml-core~=1.19.0->azureml.widgets) (3.1.1)
# Requirement already satisfied: six in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrestazure>=0.4.33->azureml-core~=1.19.0->azureml.widgets) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.19.0->azureml.widgets) (2020.12.5)
# Requirement already satisfied: isodate>=0.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.19.0->azureml.widgets) (0.6.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.19.0->azureml.widgets) (1.3.0)
# Requirement already satisfied: backports.weakref in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from backports.tempfile->azureml-core~=1.19.0->azureml.widgets) (1.0.post1)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.19.0->azureml.widgets) (1.14.4)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ndg-httpsclient->azureml-core~=1.19.0->azureml.widgets) (0.4.8)
# Requirement already satisfied: jeepney>=0.6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from SecretStorage->azureml-core~=1.19.0->azureml.widgets) (0.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.19.0->azureml.widgets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.19.0->azureml.widgets) (2.10)
# Requirement already satisfied: websocket-client>=0.32.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from docker->azureml-core~=1.19.0->azureml.widgets) (0.57.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ruamel.yaml>=0.15.35->azureml-core~=1.19.0->azureml.widgets) (0.2.2)
# Requirement already satisfied: setuptools>=18.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->azureml.widgets) (50.3.0.post20201006)
# Requirement already satisfied: pickleshare in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->azureml.widgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->azureml.widgets) (3.0.5)
# Requirement already satisfied: decorator in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->azureml.widgets) (4.4.2)
# Requirement already satisfied: backcall in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->azureml.widgets) (0.2.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->azureml.widgets) (4.8.0)
# Requirement already satisfied: jedi>=0.10 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->azureml.widgets) (0.17.2)
# Requirement already satisfied: pygments in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->azureml.widgets) (2.7.3)
# Requirement already satisfied: jupyter-core in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->azureml.widgets) (4.7.0)
# Requirement already satisfied: ipython-genutils in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->azureml.widgets) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->azureml.widgets) (3.2.0)
# Requirement already satisfied: tornado>=4.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->azureml.widgets) (6.1)
# Requirement already satisfied: jupyter-client in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->azureml.widgets) (6.1.7)
# Requirement already satisfied: notebook>=4.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (6.1.5)
# Requirement already satisfied: zipp>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle->azureml-core~=1.19.0->azureml.widgets) (3.4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core~=1.19.0->azureml.widgets) (3.1.0)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.19.0->azureml.widgets) (2.20)
# Requirement already satisfied: wcwidth in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->azureml.widgets) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->azureml.widgets) (0.6.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->azureml.widgets) (0.7.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->azureml.widgets) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->azureml.widgets) (20.3.0)
# Requirement already satisfied: pyzmq>=13 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->azureml.widgets) (20.0.0)
# Requirement already satisfied: nbconvert in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (5.6.1)
# Requirement already satisfied: Send2Trash in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (1.5.0)
# Requirement already satisfied: jinja2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (2.11.2)
# Requirement already satisfied: terminado>=0.8.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (0.9.1)
# Requirement already satisfied: prometheus-client in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (0.9.0)
# Requirement already satisfied: argon2-cffi in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (20.1.0)
# Requirement already satisfied: defusedxml in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (0.6.0)
# Requirement already satisfied: bleach in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (3.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (0.3)
# Requirement already satisfied: testpath in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (1.4.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (1.1.1)
# Requirement already satisfied: webencodings in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (0.5.1)
# Requirement already satisfied: packaging in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (20.7)
# Requirement already satisfied: pyparsing>=2.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml.widgets) (2.4.7)
# ERROR: azureml-train-core 1.18.0.post1 has requirement azureml-core~=1.18.0, but you'll have azureml-core 1.19.0 which is incompatible.
# ERROR: azureml-train-core 1.18.0.post1 has requirement azureml-telemetry~=1.18.0, but you'll have azureml-telemetry 1.19.0 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.18.0.post1 has requirement azureml-core~=1.18.0, but you'll have azureml-core 1.19.0 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.18.0.post1 has requirement azureml-telemetry~=1.18.0, but you'll have azureml-telemetry 1.19.0 which is incompatible.
# ERROR: azureml-train-automl-client 1.18.0 has requirement azureml-core~=1.18.0, but you'll have azureml-core 1.19.0 which is incompatible.
# ERROR: azureml-train-automl-client 1.18.0 has requirement azureml-telemetry~=1.18.0, but you'll have azureml-telemetry 1.19.0 which is incompatible.
# ERROR: azureml-sdk 1.18.0 has requirement azureml-core~=1.18.0, but you'll have azureml-core 1.19.0 which is incompatible.
# ERROR: azureml-pipeline-core 1.18.0 has requirement azureml-core~=1.18.0, but you'll have azureml-core 1.19.0 which is incompatible.
# ERROR: azureml-defaults 1.18.0 has requirement azureml-core~=1.18.0, but you'll have azureml-core 1.19.0 which is incompatible.
# ERROR: azureml-contrib-services 1.18.0 has requirement azureml-core~=1.18.0, but you'll have azureml-core 1.19.0 which is incompatible.
# ERROR: azureml-contrib-server 1.18.0 has requirement azureml-core~=1.18.0, but you'll have azureml-core 1.19.0 which is incompatible.
# ERROR: azureml-contrib-pipeline-steps 1.18.0 has requirement azureml-core~=1.18.0, but you'll have azureml-core 1.19.0 which is incompatible.
# ERROR: azureml-contrib-notebook 1.18.0 has requirement azureml-core~=1.18.0, but you'll have azureml-core 1.19.0 which is incompatible.
# ERROR: azureml-automl-core 1.18.0.post2 has requirement azureml-telemetry~=1.18.0, but you'll have azureml-telemetry 1.19.0 which is incompatible.
# Installing collected packages: azureml-core, azureml-telemetry, azureml.widgets
#   Attempting uninstall: azureml-core
#     Found existing installation: azureml-core 1.18.0.post4
#     Uninstalling azureml-core-1.18.0.post4:
#       Successfully uninstalled azureml-core-1.18.0.post4
#   Attempting uninstall: azureml-telemetry
#     Found existing installation: azureml-telemetry 1.18.0.post1
#     Uninstalling azureml-telemetry-1.18.0.post1:
#       Successfully uninstalled azureml-telemetry-1.18.0.post1
# Successfully installed azureml-core-1.19.0 azureml-telemetry-1.19.0 azureml.widgets

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.18.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-130072
# aml-quickstarts-130072
# southcentralus
# 2248b1c7-a065-4265-9476-038b58f0650e

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'exp-automl'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: exp-automl,
# Workspace: quick-starts-ws-130072)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "automl-cluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'accuracy'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Submitted PipelineRun 722a3a69-2ad2-41d0-87d4-f41cd03b5018
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/exp-automl/runs/722a3a69-2ad2-41d0-87d4-f41cd03b5018?wsid=/subscriptions/2248b1c7-a065-4265-9476-038b58f0650e/resourcegroups/aml-quickstarts-130072/workspaces/quick-starts-ws-130072

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 722a3a69-2ad2-41d0-87d4-f41cd03b5018
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/exp-automl/runs/722a3a69-2ad2-41d0-87d4-f41cd03b5018?wsid=/subscriptions/2248b1c7-a065-4265-9476-038b58f0650e/resourcegroups/aml-quickstarts-130072/workspaces/quick-starts-ws-130072
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '722a3a69-2ad2-41d0-87d4-f41cd03b5018', 'status': 'Completed', 'startTimeUtc': '2020-12-11T03:03:22.05537Z', 'endTimeUtc': '2020-12-11T03:03:25.562615Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg130072.blob.core.windows.net/azureml/ExperimentRun/dcid.722a3a69-2ad2-41d0-87d4-f41cd03b5018/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=8BWxrxuQh0kQOD9yEDqJgz7xzBLwFcFcjOCgHklvTkM%3D&st=2020-12-11T02%3A53%3A26Z&se=2020-12-11T11%3A03%3A26Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg130072.blob.core.windows.net/azureml/ExperimentRun/dcid.722a3a69-2ad2-41d0-87d4-f41cd03b5018/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=HDdsqomd4hsNsV06IKveyeSgkuQno%2BlZx0%2BkWYIMwPA%3D&st=2020-12-11T02%3A53%3A26Z&se=2020-12-11T11%3A03%3A26Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg130072.blob.core.windows.net/azureml/ExperimentRun/dcid.722a3a69-2ad2-41d0-87d4-f41cd03b5018/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=JqKSAeqWf6lsXCXJEyub%2FB53UsQl4%2Bd1NpjU7ML%2FaTM%3D&st=2020-12-11T02%3A53%3A26Z&se=2020-12-11T11%3A03%3A26Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/cca2be18-875b-4e0f-adb1-133f146248c5/metrics_data
# Downloaded azureml/cca2be18-875b-4e0f-adb1-133f146248c5/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_29  \
# average_precision_score_weighted                    [0.9542681202203916]
# f1_score_macro                                      [0.7650087243425018]
# accuracy                                            [0.9147192716236723]
# precision_score_macro                               [0.7948144877121203]
# log_loss                                            [0.1991622251629218]
# AUC_macro                                            [0.945518822925755]
# recall_score_micro                                  [0.9147192716236723]
# AUC_weighted                                         [0.945518822925755]
# weighted_accuracy                                    [0.957503744982689]
# precision_score_weighted                            [0.9082427276166108]
# matthews_correlation                                [0.5346413710313234]
# AUC_micro                                             [0.97996679569219]
# f1_score_weighted                                   [0.9105638077637765]
# precision_score_micro                               [0.9147192716236723]
# recall_score_weighted                               [0.9147192716236723]
# average_precision_score_macro                        [0.819873787130065]
# recall_score_macro                                   [0.742390899643788]
# average_precision_score_micro                       [0.9809013438223185]
# balanced_accuracy                                    [0.742390899643788]
# f1_score_micro                                      [0.9147192716236722]
# norm_macro_recall                                  [0.48478179928757603]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_8  \
# average_precision_score_weighted                   [0.9382344518388743]
# f1_score_macro                                     [0.7034797905817874]
# accuracy                                           [0.9025796661608497]
# precision_score_macro                              [0.7653000170128346]
# log_loss                                          [0.22597334530581215]
# AUC_macro                                          [0.9207868155236576]
# recall_score_micro                                 [0.9025796661608497]
# AUC_weighted                                       [0.9207868155236575]
# weighted_accuracy                                  [0.9602165507712037]
# precision_score_weighted                           [0.8887696135205639]
# matthews_correlation                              [0.42527474546043575]
# AUC_micro                                          [0.9696995263435425]
# f1_score_weighted                                  [0.8920347468246255]
# precision_score_micro                              [0.9025796661608497]
# recall_score_weighted                              [0.9025796661608497]
# average_precision_score_macro                      [0.7622057782851999]
# recall_score_macro                                 [0.6704283806337722]
# average_precision_score_micro                      [0.9675195605818652]
# balanced_accuracy                                  [0.6704283806337722]
# f1_score_micro                                     [0.9025796661608497]
# norm_macro_recall                                  [0.3408567612675444]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_1  \
# average_precision_score_weighted                   [0.9505970434373063]
# f1_score_macro                                     [0.7416848907681176]
# accuracy                                           [0.9071320182094081]
# precision_score_macro                              [0.7723958081530135]
# log_loss                                           [0.1874363495858499]
# AUC_macro                                          [0.9392346349984347]
# recall_score_micro                                 [0.9071320182094081]
# AUC_weighted                                       [0.9392346349984347]
# weighted_accuracy                                  [0.9537972210153172]
# precision_score_weighted                           [0.8991976076061607]
# matthews_correlation                                [0.488678780261868]
# AUC_micro                                          [0.9781770788959222]
# f1_score_weighted                                  [0.9021127651963996]
# precision_score_micro                              [0.9071320182094081]
# recall_score_weighted                              [0.9071320182094081]
# average_precision_score_macro                      [0.8065229883244922]
# recall_score_macro                                 [0.7191727470931578]
# average_precision_score_micro                      [0.9791945367231853]
# balanced_accuracy                                  [0.7191727470931578]
# f1_score_micro                                     [0.9071320182094081]
# norm_macro_recall                                 [0.43834549418631563]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_23  \
# average_precision_score_weighted                    [0.9295644805629836]
# f1_score_macro                                      [0.4703423886834914]
# accuracy                                            [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# log_loss                                           [0.22870508543089368]
# AUC_macro                                           [0.9052375024775539]
# recall_score_micro                                  [0.8880121396054628]
# AUC_weighted                                         [0.905237502477554]
# weighted_accuracy                                   [0.9843450583187134]
# precision_score_weighted                             [0.788565560086672]
# matthews_correlation                                               [0.0]
# AUC_micro                                           [0.9686111066337234]
# f1_score_weighted                                   [0.8353395018439429]
# precision_score_micro                               [0.8880121396054628]
# recall_score_weighted                               [0.8880121396054628]
# average_precision_score_macro                       [0.7289781966961968]
# recall_score_macro                                                 [0.5]
# average_precision_score_micro                       [0.9700719876888315]
# balanced_accuracy                                                  [0.5]
# f1_score_micro                                      [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_7  \
# average_precision_score_weighted                   [0.9521779928580898]
# f1_score_macro                                     [0.7545314407202168]
# accuracy                                           [0.9092564491654022]
# precision_score_macro                              [0.7764683633219862]
# log_loss                                          [0.20857711399223305]
# AUC_macro                                          [0.9402552945556797]
# recall_score_micro                                 [0.9092564491654022]
# AUC_weighted                                       [0.9402552945556797]
# weighted_accuracy                                  [0.9520362829582333]
# precision_score_weighted                           [0.9033988812665149]
# matthews_correlation                                [0.511891723662503]
# AUC_micro                                          [0.9784595688045297]
# f1_score_weighted                                  [0.9057668560850253]
# precision_score_micro                              [0.9092564491654022]
# recall_score_weighted                              [0.9092564491654022]
# average_precision_score_macro                      [0.8131164655218285]
# recall_score_macro                                 [0.7369467645462511]
# average_precision_score_micro                      [0.9794670997930398]
# balanced_accuracy                                  [0.7369467645462511]
# f1_score_micro                                      [0.909256449165402]
# norm_macro_recall                                 [0.47389352909250215]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_0  \
# average_precision_score_weighted                   [0.9531771295804466]
# f1_score_macro                                     [0.7653697272147331]
# accuracy                                           [0.9116843702579667]
# precision_score_macro                              [0.7819118765348991]
# log_loss                                          [0.17775706110025447]
# AUC_macro                                          [0.9450464668693166]
# recall_score_micro                                 [0.9116843702579667]
# AUC_weighted                                       [0.9450464668693167]
# weighted_accuracy                                  [0.9514937218005303]
# precision_score_weighted                           [0.9072720074188747]
# matthews_correlation                               [0.5323740218566827]
# AUC_micro                                           [0.979695082216353]
# f1_score_weighted                                  [0.9091539479147899]
# precision_score_micro                              [0.9116843702579667]
# recall_score_weighted                              [0.9116843702579667]
# average_precision_score_macro                      [0.8151093723721079]
# recall_score_macro                                 [0.7513392683482543]
# average_precision_score_micro                      [0.9806603102489483]
# balanced_accuracy                                  [0.7513392683482543]
# f1_score_micro                                     [0.9116843702579667]
# norm_macro_recall                                  [0.5026785366965085]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_13  \
# average_precision_score_weighted                    [0.9407605141082803]
# f1_score_macro                                      [0.6758141851921042]
# accuracy                                            [0.9040971168437025]
# precision_score_macro                               [0.7904985195432186]
# log_loss                                           [0.21257931095523555]
# AUC_macro                                           [0.9220941303739763]
# recall_score_micro                                  [0.9040971168437025]
# AUC_weighted                                        [0.9220941303739764]
# weighted_accuracy                                   [0.9707182537050006]
# precision_score_weighted                            [0.8882017194414148]
# matthews_correlation                               [0.39717875416985243]
# AUC_micro                                           [0.9733607502976184]
# f1_score_weighted                                   [0.8869242959454992]
# precision_score_micro                               [0.9040971168437025]
# recall_score_weighted                               [0.9040971168437025]
# average_precision_score_macro                       [0.7712048002604608]
# recall_score_macro                                  [0.6357588353737262]
# average_precision_score_micro                       [0.9745407471121207]
# balanced_accuracy                                   [0.6357588353737262]
# f1_score_micro                                      [0.9040971168437025]
# norm_macro_recall                                   [0.2715176707474525]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_18  \
# average_precision_score_weighted                    [0.9523973441226696]
# f1_score_macro                                      [0.7585358306343567]
# accuracy                                             [0.908649468892261]
# precision_score_macro                               [0.7730122814372734]
# log_loss                                           [0.18276368510928603]
# AUC_macro                                           [0.9426115177077949]
# recall_score_micro                                   [0.908649468892261]
# AUC_weighted                                        [0.9426115177077949]
# weighted_accuracy                                   [0.9490115533678862]
# precision_score_weighted                             [0.904434899217646]
# matthews_correlation                                [0.5183910930168123]
# AUC_micro                                           [0.9788298359817722]
# f1_score_weighted                                   [0.9062804699821092]
# precision_score_micro                                [0.908649468892261]
# recall_score_weighted                                [0.908649468892261]
# average_precision_score_macro                       [0.8128587183770495]
# recall_score_macro                                  [0.7460780554490439]
# average_precision_score_micro                       [0.9798331125567491]
# balanced_accuracy                                   [0.7460780554490439]
# f1_score_micro                                       [0.908649468892261]
# norm_macro_recall                                  [0.49215611089808786]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_21  \
# average_precision_score_weighted                    [0.9554038898439862]
# f1_score_macro                                       [0.752863672918342]
# accuracy                                            [0.9125948406676783]
# precision_score_macro                               [0.7916268932733324]
# log_loss                                            [0.1810024477698423]
# AUC_macro                                           [0.9456197774554642]
# recall_score_micro                                  [0.9125948406676783]
# AUC_weighted                                         [0.945619777455464]
# weighted_accuracy                                     [0.95897069514398]
# precision_score_weighted                              [0.90447440932125]
# matthews_correlation                                [0.5132237259058233]
# AUC_micro                                           [0.9801586530380099]
# f1_score_weighted                                   [0.9070473633430505]
# precision_score_micro                               [0.9125948406676783]
# recall_score_weighted                               [0.9125948406676783]
# average_precision_score_macro                       [0.8251485061910754]
# recall_score_macro                                  [0.7258010139910012]
# average_precision_score_micro                       [0.9810419752109084]
# balanced_accuracy                                   [0.7258010139910012]
# f1_score_micro                                      [0.9125948406676783]
# norm_macro_recall                                  [0.45160202798200233]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_10  ...  \
# average_precision_score_weighted                    [0.9498586901696163]  ...
# f1_score_macro                                      [0.7410400670578374]  ...
# accuracy                                            [0.9110773899848255]  ...
# precision_score_macro                               [0.7908196055445871]  ...
# log_loss                                           [0.18485719214536023]  ...
# AUC_macro                                           [0.9406868983248957]  ...
# recall_score_micro                                  [0.9110773899848255]  ...
# AUC_weighted                                        [0.9406868983248957]  ...
# weighted_accuracy                                   [0.9611104717292754]  ...
# precision_score_weighted                             [0.901311576372359]  ...
# matthews_correlation                                [0.4937290323447371]  ...
# AUC_micro                                           [0.9781896974539526]  ...
# f1_score_weighted                                   [0.9038810538459678]  ...
# precision_score_micro                               [0.9110773899848255]  ...
# recall_score_weighted                               [0.9110773899848255]  ...
# average_precision_score_macro                       [0.8022857542994071]  ...
# recall_score_macro                                  [0.7095528918378726]  ...
# average_precision_score_micro                       [0.9792469103727843]  ...
# balanced_accuracy                                   [0.7095528918378726]  ...
# f1_score_micro                                      [0.9110773899848255]  ...
# norm_macro_recall                                  [0.41910578367574525]  ...
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_2  \
# average_precision_score_weighted                   [0.9355107396565083]
# f1_score_macro                                     [0.5760716224159137]
# accuracy                                           [0.8959028831562974]
# precision_score_macro                              [0.8014232242339833]
# log_loss                                          [0.23397074102169446]
# AUC_macro                                          [0.9081800028526601]
# recall_score_micro                                 [0.8959028831562974]
# AUC_weighted                                       [0.9081800028526601]
# weighted_accuracy                                  [0.9798623465200952]
# precision_score_weighted                            [0.877705032842874]
# matthews_correlation                               [0.2638243207923601]
# AUC_micro                                          [0.9694139048219931]
# f1_score_weighted                                  [0.8618188389474167]
# precision_score_micro                              [0.8959028831562974]
# recall_score_weighted                              [0.8959028831562974]
# average_precision_score_macro                      [0.7576687468800813]
# recall_score_macro                                 [0.5577288565093443]
# average_precision_score_micro                      [0.9701804732880351]
# balanced_accuracy                                  [0.5577288565093443]
# f1_score_micro                                     [0.8959028831562974]
# norm_macro_recall                                 [0.11545771301868868]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_22  \
# average_precision_score_weighted                    [0.9250669632858293]
# f1_score_macro                                      [0.5221946040183121]
# accuracy                                            [0.8925644916540213]
# precision_score_macro                               [0.8466360856269113]
# log_loss                                           [0.26361762089617685]
# AUC_macro                                           [0.8676889007440997]
# recall_score_micro                                  [0.8925644916540213]
# AUC_weighted                                        [0.8676889007440997]
# weighted_accuracy                                   [0.9835114985828909]
# precision_score_weighted                            [0.8828268203607541]
# matthews_correlation                               [0.19076438824349456]
# AUC_micro                                           [0.9612344081366673]
# f1_score_weighted                                   [0.8486461044266225]
# precision_score_micro                               [0.8925644916540213]
# recall_score_weighted                               [0.8925644916540213]
# average_precision_score_macro                       [0.7325711816656221]
# recall_score_macro                                  [0.5262458622535644]
# average_precision_score_micro                       [0.9621170853849272]
# balanced_accuracy                                   [0.5262458622535644]
# f1_score_micro                                      [0.8925644916540213]
# norm_macro_recall                                   [0.0524917245071288]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_17  \
# average_precision_score_weighted                    [0.9385182115272048]
# f1_score_macro                                      [0.7008431471845663]
# accuracy                                            [0.9044006069802731]
# precision_score_macro                                [0.776355093319379]
# log_loss                                            [0.2253916219078061]
# AUC_macro                                           [0.9200699457438866]
# recall_score_micro                                  [0.9044006069802731]
# AUC_weighted                                        [0.9200699457438866]
# weighted_accuracy                                   [0.9639989574179747]
# precision_score_weighted                            [0.8900794345597077]
# matthews_correlation                               [0.42623303560744186]
# AUC_micro                                           [0.9700583723441736]
# f1_score_weighted                                    [0.892342935520704]
# precision_score_micro                               [0.9044006069802731]
# recall_score_weighted                               [0.9044006069802731]
# average_precision_score_macro                        [0.763006679195249]
# recall_score_macro                                  [0.6643488803309086]
# average_precision_score_micro                       [0.9679694834873818]
# balanced_accuracy                                   [0.6643488803309086]
# f1_score_micro                                      [0.9044006069802731]
# norm_macro_recall                                   [0.3286977606618171]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_19  \
# average_precision_score_weighted                    [0.9406621105972124]
# f1_score_macro                                      [0.5873795815655067]
# accuracy                                            [0.8980273141122913]
# precision_score_macro                               [0.8237229281103775]
# log_loss                                           [0.23706109433870007]
# AUC_macro                                           [0.9212739905936311]
# recall_score_micro                                  [0.8980273141122913]
# AUC_weighted                                        [0.9212739905936311]
# weighted_accuracy                                   [0.9807472995251469]
# precision_score_weighted                            [0.8838293232406824]
# matthews_correlation                                 [0.289772572317636]
# AUC_micro                                           [0.9721921981389929]
# f1_score_weighted                                   [0.8652131779705882]
# precision_score_micro                               [0.8980273141122913]
# recall_score_weighted                               [0.8980273141122913]
# average_precision_score_macro                       [0.7713214739798709]
# recall_score_macro                                    [0.56484568775968]
# average_precision_score_micro                       [0.9734082584025308]
# balanced_accuracy                                     [0.56484568775968]
# f1_score_micro                                      [0.8980273141122913]
# norm_macro_recall                                  [0.12969137551936005]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_11  \
# average_precision_score_weighted                    [0.9410281881536726]
# f1_score_macro                                      [0.7014409944746076]
# accuracy                                            [0.9083459787556905]
# precision_score_macro                               [0.8023269698119038]
# log_loss                                           [0.21709496708504772]
# AUC_macro                                           [0.9098244502609072]
# recall_score_micro                                  [0.9083459787556905]
# AUC_weighted                                        [0.9098244502609073]
# weighted_accuracy                                   [0.9701362565487615]
# precision_score_weighted                            [0.8948809492824611]
# matthews_correlation                               [0.43913887192659884]
# AUC_micro                                           [0.9714910852650703]
# f1_score_weighted                                   [0.8943159652390001]
# precision_score_micro                               [0.9083459787556905]
# recall_score_weighted                               [0.9083459787556905]
# average_precision_score_macro                        [0.778764693607036]
# recall_score_macro                                  [0.6594655522768488]
# average_precision_score_micro                       [0.9726607402338695]
# balanced_accuracy                                   [0.6594655522768488]
# f1_score_micro                                      [0.9083459787556905]
# norm_macro_recall                                  [0.31893110455369755]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_15  \
# average_precision_score_weighted                    [0.9363779145144203]
# f1_score_macro                                      [0.5088795735932309]
# accuracy                                            [0.8898330804248862]
# precision_score_macro                                [0.758388107612351]
# log_loss                                           [0.24660061006703418]
# AUC_macro                                           [0.9149768360294677]
# recall_score_micro                                  [0.8898330804248862]
# AUC_weighted                                        [0.9149768360294676]
# weighted_accuracy                                   [0.9819537191538347]
# precision_score_weighted                            [0.8619005176775351]
# matthews_correlation                               [0.13934714202242665]
# AUC_micro                                           [0.9706867212703296]
# f1_score_weighted                                   [0.8445439832998273]
# precision_score_micro                               [0.8898330804248862]
# recall_score_weighted                               [0.8898330804248862]
# average_precision_score_macro                       [0.7553865011572076]
# recall_score_macro                                  [0.5187872675035705]
# average_precision_score_micro                       [0.9719806485949514]
# balanced_accuracy                                   [0.5187872675035705]
# f1_score_micro                                      [0.8898330804248862]
# norm_macro_recall                                  [0.03757453500714103]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_16  \
# average_precision_score_weighted                    [0.9406923437495528]
# f1_score_macro                                      [0.5721265851574554]
# accuracy                                            [0.8974203338391502]
# precision_score_macro                               [0.8457945828919955]
# log_loss                                           [0.24146285552032604]
# AUC_macro                                           [0.9182935164963406]
# recall_score_micro                                  [0.8974203338391502]
# AUC_weighted                                        [0.9182935164963406]
# weighted_accuracy                                   [0.9824263762674852]
# precision_score_weighted                            [0.8871890780854338]
# matthews_correlation                                [0.2758940136253946]
# AUC_micro                                           [0.9715817178278578]
# f1_score_weighted                                   [0.8616414182166596]
# precision_score_micro                               [0.8974203338391502]
# recall_score_weighted                               [0.8974203338391502]
# average_precision_score_macro                       [0.7750724476462016]
# recall_score_macro                                  [0.5550308698575708]
# average_precision_score_micro                       [0.9723869909943501]
# balanced_accuracy                                   [0.5550308698575708]
# f1_score_micro                                      [0.8974203338391502]
# norm_macro_recall                                  [0.11006173971514155]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_20  \
# average_precision_score_weighted                    [0.9381781302957436]
# f1_score_macro                                      [0.7034797905817874]
# accuracy                                            [0.9025796661608497]
# precision_score_macro                               [0.7653000170128346]
# log_loss                                           [0.22599597906353744]
# AUC_macro                                             [0.92073587516463]
# recall_score_micro                                  [0.9025796661608497]
# AUC_weighted                                        [0.9207358751646298]
# weighted_accuracy                                   [0.9602165507712037]
# precision_score_weighted                            [0.8887696135205639]
# matthews_correlation                               [0.42527474546043575]
# AUC_micro                                            [0.969689763079665]
# f1_score_weighted                                   [0.8920347468246255]
# precision_score_micro                               [0.9025796661608497]
# recall_score_weighted                               [0.9025796661608497]
# average_precision_score_macro                        [0.762203283894697]
# recall_score_macro                                  [0.6704283806337722]
# average_precision_score_micro                       [0.9674758514382147]
# balanced_accuracy                                   [0.6704283806337722]
# f1_score_micro                                      [0.9025796661608497]
# norm_macro_recall                                   [0.3408567612675444]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_28  \
# average_precision_score_weighted                    [0.9542580510013013]
# f1_score_macro                                      [0.7689470436441154]
# accuracy                                            [0.9180576631259484]
# precision_score_macro                               [0.8088688286129888]
# log_loss                                           [0.17849106096274014]
# AUC_macro                                           [0.9454938158404141]
# recall_score_micro                                  [0.9180576631259484]
# AUC_weighted                                         [0.945493815840414]
# weighted_accuracy                                   [0.9620862540020929]
# precision_score_weighted                            [0.9108768117513293]
# matthews_correlation                                [0.5453452100755443]
# AUC_micro                                           [0.9799538087091078]
# f1_score_weighted                                   [0.9129877893997055]
# precision_score_micro                               [0.9180576631259484]
# recall_score_weighted                               [0.9180576631259484]
# average_precision_score_macro                       [0.8198479926269683]
# recall_score_macro                                  [0.7407182034909892]
# average_precision_score_micro                       [0.9808885862979373]
# balanced_accuracy                                   [0.7407182034909892]
# f1_score_micro                                      [0.9180576631259484]
# norm_macro_recall                                   [0.4814364069819783]
#
#                                  cca2be18-875b-4e0f-adb1-133f146248c5_6
# average_precision_score_weighted                    [0.952354416901938]
# f1_score_macro                                     [0.7560397252132639]
# accuracy                                           [0.9101669195751139]
# precision_score_macro                              [0.7794931081546599]
# log_loss                                           [0.1822581527611655]
# AUC_macro                                          [0.9422234447908389]
# recall_score_micro                                 [0.9101669195751139]
# AUC_weighted                                       [0.9422234447908389]
# weighted_accuracy                                  [0.9530455225942402]
# precision_score_weighted                           [0.9041230730193003]
# matthews_correlation                               [0.5152407922685548]
# AUC_micro                                          [0.9789531662679233]
# f1_score_weighted                                  [0.9065182421980865]
# precision_score_micro                              [0.9101669195751139]
# recall_score_weighted                              [0.9101669195751139]
# average_precision_score_macro                      [0.8130183856042391]
# recall_score_macro                                 [0.7374594097957384]
# average_precision_score_micro                      [0.9799175214338409]
# balanced_accuracy                                  [0.7374594097957384]
# f1_score_micro                                     [0.9101669195751139]
# norm_macro_recall                                 [0.47491881959147686]
#
# [21 rows x 26 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/cca2be18-875b-4e0f-adb1-133f146248c5/model_data
# Downloaded azureml/cca2be18-875b-4e0f-adb1-133f146248c5/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                 reg_alpha=0,
#                                                                                                                                 reg_lambda=2.0833333333333335,
#                                                                                                                                 scale_pos_weight=1,
#                                                                                                                                 seed=None,
#                                                                                                                                 silent=None,
#                                                                                                                                 subsample=1,
#                                                                                                                                 tree_method='auto',
#                                                                                                                                 verbose=-10,
#                                                                                                                                 verbosity=0))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.16666666666666666,
#                                                                                          0.16666666666666666,
#                                                                                          0.16666666666666666,
#                                                                                          0.4166666666666667,
#                                                                                          0.08333333333333333]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('9',
#                                              Pipeline(memory=None,
#                                                       steps=[('sparsenormalizer',
#                                                               <azureml.automl.runtime.shared.model_wrappers.SparseNormalizer object at 0x7fd9edee7c18>),
#                                                              ('xgboostclassifier',
#                                                               XGBoostClassifier(base_score=0.5,
#                                                                                 booster='gbtree',
#                                                                                 colsample_bylevel=1,
#                                                                                 colsample_bynode=1,
#                                                                                 colsample_bytree=0.8,
#                                                                                 eta=0.2,
#                                                                                 ga...
#                                                                                 n_jobs=1,
#                                                                                 nthread=None,
#                                                                                 objective='reg:logistic',
#                                                                                 random_state=0,
#                                                                                 reg_alpha=0,
#                                                                                 reg_lambda=2.0833333333333335,
#                                                                                 scale_pos_weight=1,
#                                                                                 seed=None,
#                                                                                 silent=None,
#                                                                                 subsample=1,
#                                                                                 tree_method='auto',
#                                                                                 verbose=-10,
#                                                                                 verbosity=0))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.16666666666666666, 0.16666666666666666,
#                                          0.16666666666666666, 0.4166666666666667,
#                                          0.08333333333333333]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_a0cdadea_3b5d_11eb_bc94_000d3aed06f3row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_a0cdadea_3b5d_11eb_bc94_000d3aed06f3row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a0cdadea_3b5d_11eb_bc94_000d3aed06f3row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a0cdadea_3b5d_11eb_bc94_000d3aed06f3row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_a0cdadea_3b5d_11eb_bc94_000d3aed06f3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a0cdadea_3b5d_11eb_bc94_000d3aed06f3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a0cdadea_3b5d_11eb_bc94_000d3aed06f3row0_col0" class="data row0 col0" >28630</td>
#                         <td id="T_a0cdadea_3b5d_11eb_bc94_000d3aed06f3row0_col1" class="data row0 col1" >628</td>
#             </tr>
#             <tr>
#                         <th id="T_a0cdadea_3b5d_11eb_bc94_000d3aed06f3level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a0cdadea_3b5d_11eb_bc94_000d3aed06f3row1_col0" class="data row1 col0" >1453</td>
#                         <td id="T_a0cdadea_3b5d_11eb_bc94_000d3aed06f3row1_col1" class="data row1 col1" >2239</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="pipeline_with_automlstep", description="This is pipeline created using automl step", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: pipeline_with_automlstep,
# Id: 2303a0b8-2678-42d8-bd2f-d7a5660067a9,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/2248b1c7-a065-4265-9476-038b58f0650e/resourceGroups/aml-quickstarts-130072/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-130072/PipelineRuns/PipelineSubmit/2303a0b8-2678-42d8-bd2f-d7a5660067a9)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "exp-automl"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  d1d6148c-0083-4d7a-a70c-5ae843c6ec40

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["exp-automl"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
